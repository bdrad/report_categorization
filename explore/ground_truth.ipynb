# %%
# !pip3 install pyspellchecker
# Out:
# Requirement already satisfied: pyspellchecker in /Applications/anaconda3/lib/python3.6/site-packages (0.5.2)
# WARNING: You are using pip version 19.2.3, however version 19.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import pandas as pd
from spellchecker import SpellChecker
import re

# %%
df = pd.read_csv('../data/inputs/ct_desc.csv')
df['Hashtag']
# Out:
# 0        [unchanged]_intramural_hematoma, ascending_aor...
# 1        [unchange]_[right]_pleural effusion, [decrease...
# 2        [negx]_pulmonary_embolism, [decrease]_[bilater...
# 3                                       [negex]_metastasis
# 4           [left]_[supraclavicular]_LN, [risk]_metastasis
# 5                                       [negex]_metastasis
# 6        [negx]_pulmonary_embolism, [improved]_Erdheim_...
# 7                                       [negex]_metastasis
# 8        [negex]_pulmonary_embolism, [bilateral]_[moder...
# 9        [negex]_metastasis, [RML]_m]_pulmonary_nodu...
# 10                                                     NaN
# 11       [negex]_pulmonary_embolism, consolidation, [ri...
# 12                           [left]_m]_pulmonary_nodule
# 13                  [unchanged]_[RLL]_m]_pleural_nodule
# 14                [unchanged]_[RLL]_m]_pulmonary_nodule
# 15                                                     NaN
# 16       [increase]_[RLL]_m]_pulmonary_nodule, [risk...
# 17       [unchaged]_[RML]_m]_pulmonary_nodule, [LUL]...
# 18       [unchanged]_[RUL]_m]_[ground_glass]_pulmona...
# 19                                      [negex]_metastasis
# 20                                                     NaN
# 21       [RISK]_thoracic_abscess, sternal_osteomyelitis...
# 22       [unchanged]_m]_[LLL]_pulmonary_nodule, [new...
# 23       [new]_[RLL]_m]_[ground_glass]_pulmonary_nod...
# 24       [right]_[small]_pneumothorax, [right]_bronchop...
# 25       [s/p]_coronary_stenting, [s/p]_CABG, [right]_p...
# 26                                                     NaN
# 27       [unchanged]_endovascular_repair, [unchanged]_t...
# 28       [unchanged]_[mid]_[distal]_[5.6cm]_[6.0cm]_des...
# 29       [negex]_acute_aortic_syndrome, [negex]_thoraci...
#                                ...
# 19255                                                  NaN
# 19256                                                  NaN
# 19257                                                  NaN
# 19258                                                  NaN
# 19259                                                  NaN
# 19260                                                  NaN
# 19261                                                  NaN
# 19262                                                  NaN
# 19263                                                  NaN
# 19264                                                  NaN
# 19265                                                  NaN
# 19266                                                  NaN
# 19267                                                  NaN
# 19268                                                  NaN
# 19269                                                  NaN
# 19270                                                  NaN
# 19271                                                  NaN
# 19272                                                  NaN
# 19273                                                  NaN
# 19274                                                  NaN
# 19275                                                  NaN
# 19276                                                  NaN
# 19277                                                  NaN
# 19278                                                  NaN
# 19279                                                  NaN
# 19280                                                  NaN
# 19281                                                  NaN
# 19282                                                  NaN
# 19283                                                  NaN
# 19284                                                  NaN
# Name: Hashtag, Length: 19285, dtype: object

# %%
def process_hashtag(tags):
    
    descriptors = set()
    entities = set()
    
    tags = tags.split(', ')
    for tag in tags:
        tag = tag.split('_')
        
        for i, v in enumerate(tag):
            if v[0] == '[':
                descriptors.add(v)
            else:
                entities.add("_".join(tag[i:]))
                break
        
    return descriptors, entities

# %%
uncleaned_descriptors = set()
uncleaned_entities = set()

for hashtag in df['Hashtag']:
    if isinstance(hashtag, str):
        d, e = process_hashtag(hashtag)
        uncleaned_descriptors.update(d)
        uncleaned_entities.update(e)

# %%
def descriptor_cleaner(desc):
    descriptors_cleaned = set()
    
    for d in desc:
        temp = re.sub(r'[^a-zA-Z]', "", d)
        
        descriptors_cleaned.add(temp)
    
    return descriptors_cleaned

cleaned_descriptors = descriptor_cleaner(uncleaned_descriptors)

# %%
cleaned_descriptors
# Out:
# {'',
#  'AP',
#  'BLL',
#  'BML',
#  'BUL',
#  'GGN',
#  'Gortex',
#  'L',
#  'LLL',
#  'LLLcm',
#  'LUL',
#  'RBLL',
#  'RISK',
#  'RLL',
#  'RML',
#  'RUL',
#  'SVC',
#  'T',
#  'TT',
#  'acute',
#  'age',
#  'aggravated',
#  'anterior',
#  'aortopulmonary',
#  'apex',
#  'apical',
#  'appandage',
#  'arch',
#  'atypical',
#  'axillary',
#  'azygoesophageal',
#  'basilar',
#  'bilateral',
#  'biltaeral',
#  'borderline',
#  'brachicephalic',
#  'brachiocephalic',
#  'breast',
#  'bronchus',
#  'calcified',
#  'cannular',
#  'cardiomegaly',
#  'cardiophrenic',
#  'category',
#  'catheter',
#  'cavitary',
#  'chest',
#  'chronic',
#  'clavicle',
#  'cm',
#  'comminuted',
#  'common',
#  'confirmed',
#  'costophrenic',
#  'cystic',
#  'decrease',
#  'decreased',
#  'decrese',
#  'descending',
#  'diaphragm',
#  'diffuse',
#  'distal',
#  'enhancing',
#  'esophagus',
#  'extrapleural',
#  'exudative',
#  'fatty',
#  'fissural',
#  'fissure',
#  'focal',
#  'glenoid',
#  'groud',
#  'ground',
#  'hilar',
#  'humerus',
#  'hyperenhancing',
#  'improved',
#  'increase',
#  'indeterminate',
#  'indrease',
#  'infeior',
#  'inferior',
#  'infrahilar',
#  'intercostal',
#  'internal',
#  'isthmus',
#  'large',
#  'left',
#  'lingular',
#  'lobulated',
#  'loculated',
#  'lower',
#  'lung',
#  'lytic',
#  'main',
#  'major',
#  'malignant',
#  'mandible',
#  'manubrium',
#  'massive',
#  'mediastinal',
#  'medistinal',
#  'medium',
#  'mid',
#  'mild',
#  'minor',
#  'mm',
#  'mo',
#  'moderate',
#  'mtultiple',
#  'multifocal',
#  'multile',
#  'multiple',
#  'necrotic',
#  'necrotizing',
#  'necrptic',
#  'negex',
#  'negnex',
#  'negx',
#  'new',
#  'nodular',
#  'noncalcified',
#  'old',
#  'paratracheal',
#  'part',
#  'partial',
#  'patchy',
#  'pathologic',
#  'periaortic',
#  'perigraft',
#  'perihilar',
#  'pleural',
#  'postoperative',
#  'probable',
#  'pulmonary',
#  'rd',
#  'reactive',
#  'reated',
#  'rec',
#  'recurrence',
#  'recurrent',
#  'remote',
#  'rib',
#  'right',
#  'rigk',
#  'rigt',
#  'risk',
#  'scapular',
#  'scleroci',
#  'sclerotic',
#  'segmental',
#  'serosanguineous',
#  'severe',
#  'small',
#  'solid',
#  'sp',
#  'spleen',
#  'splenic',
#  'sternal',
#  'sternoclavicular',
#  'sternum',
#  'subcarainal',
#  'subcarinal',
#  'subclavian',
#  'subpectoral',
#  'subpleural',
#  'subsegmental',
#  'superimposed',
#  'superior',
#  'supraclavicular',
#  'surrouding',
#  'teralogy',
#  'th',
#  'thoracic',
#  'thoraic',
#  'three',
#  'tiny',
#  'trace',
#  'treated',
#  'tree',
#  'two',
#  'type',
#  'uchanged',
#  'uncahnged',
#  'unchaged',
#  'unchanaged',
#  'unchange',
#  'unchanged',
#  'unhanged',
#  'upper',
#  'variable'}

# %%
uncleaned_entities
# Out:
# {'2]_CPAM',
#  '2]_Lung_RADs',
#  '2]_endoleak',
#  '3]_Lung_RADs',
#  '3]_endoleak',
#  '4]_Lung_RADs',
#  'AAH',
#  'ADH',
#  'AIS',
#  'AML_related',
#  'A]_aortic_dissection',
#  'B]_aortic_dissection',
#  'CABG',
#  'Erdheim_Chester disease',
#  'IPF',
#  'LN',
#  'LN_metastasis',
#  'LV_enlargement',
#  'Langerhans_cell_histiocytosis',
#  'MAC',
#  'MIA',
#  'Morgagni_hernia',
#  'NISP',
#  'NSIP',
#  'NTM',
#  'NTM_infection',
#  'Port_A_Cath_clot',
#  'RB_ILD',
#  'SVC_narrowing',
#  'SVC_stent',
#  'SVC_thrombosis',
#  'UIP',
#  ']mtuliple]_[subpleural]_pulmonary_nodule',
#  'abdominal_aorta_dilatation',
#  'abnormality',
#  'achalasia',
#  'acute_aortic_syndrome',
#  'acute_disease',
#  'acute_injury',
#  'acute_lung_injury',
#  'acute_rejection',
#  'adenmatous_hyperplasia',
#  'adrenal_gland_nodule',
#  'adrenal_nodule',
#  'aggravated_disease',
#  'aggravated_metastasis',
#  'air_trapping',
#  'airway_impaction',
#  'airway_infection',
#  'airway_lesion',
#  'airway_obstruction',
#  'airway_thickening',
#  'allergic_bronchopulmonary_aspergillosis',
#  'alveolar_hemorrhage',
#  'and_cystic]_pulmonary_nodule',
#  'anterior_descending]_coronary_disease',
#  'anterior_descending]_coronary_stenosis',
#  'anterior_descending]_myocardial_bridging',
#  'aorta]_intramural_hematoma',
#  'aorta]_ulcerative_plaque',
#  'aorta_pseudoaneurysm',
#  'aortic_abnormality',
#  'aortic_arch_dilatation',
#  'aortic_dissection',
#  'aortic_stent',
#  'aortic_stent_graft',
#  'aortic_valve_calcification',
#  'aplastic_anemia',
#  'arterial_aneurysm',
#  'artery]_[partial]_vascular_obstruction',
#  'artery]_stump_thrombosis',
#  'artery_aneurysm',
#  'arthritis',
#  'asceding_aorta_dilatation',
#  'ascending_aorta_dilatation',
#  'ascending_aorta_graft_repair',
#  'ascending_aorta_wall_thickening',
#  'ascending_arota_dilatation',
#  'ascites',
#  'ascneding_aorta_dilatation ',
#  'aspiration',
#  'aspiration_pneumonia',
#  'aspiration_sequela',
#  'atelectasis',
#  'atrial_appendage]_thrombus',
#  'atrial_enlargement',
#  'atrial_thrombus',
#  'atypical_infection',
#  'axillary_lymphdenopathy',
#  'bacterial_infection',
#  'bacterial_pneumonia',
#  'benign',
#  'blood_clot',
#  'bone_invasion',
#  'bone_involvement',
#  'bone_lesion',
#  'bone_lesions',
#  'bone_metastasis',
#  'breast_nodule',
#  'breast_prosthesis_calcification',
#  'breast_reconstruction',
#  'breat_mass',
#  'bronchial_obstruction',
#  'bronchial_wall_thickening',
#  'bronchiectasis',
#  'bronchiolitis_obliterans',
#  'bronchitis',
#  'broncholith',
#  'bronchopleural_fistula',
#  'bronchopneumonia',
#  'bronchus_invasion',
#  'bronchus_obstruction [RLL]_bronchial_narrowing',
#  'bulla',
#  'burst_fracture',
#  'calcification',
#  'calcified_granuloma',
#  'calcified_plaque',
#  'calcium_score',
#  'capillary_hemangiomatosis',
#  'cardiomegaly',
#  'cardiophrenic_LN',
#  'cardiovascular_disease_evaluation',
#  'category_5',
#  'catheter_fragment',
#  'cavitary_nodule',
#  'cavity]_m]_hyperdense_lesion',
#  'central_venous_obstruction',
#  'centrilobular_groud_glass_opacity',
#  'centrilobular_ground_glass_opacity',
#  'centrilobular_nodules',
#  'centrilobular_pulmonary_nodules',
#  'centrilobular_pulmonary_opacities',
#  'change]_[multiple]_pulmonary_nodule',
#  'chest_wall_defect',
#  'chest_wall_mass',
#  'chest_wall_nodule',
#  'chronic_NTM_infection',
#  'chronic_airway_disease',
#  'chronic_airway_infection',
#  'chronic_hypersensitivity_pneumonitis',
#  'chronic_infection',
#  'chronic_rejection',
#  'circulflex]_myocardiac_infarction_sequalae',
#  'circumflex]_coronary_stenosis',
#  'clavicular_fracture',
#  'coarctation_of_aorta',
#  'coccidioidomycosis',
#  'coccidiomycosis',
#  'collapse',
#  'colonic_pneumonatosis',
#  'complication',
#  'compression_deformity',
#  'compression_fracture',
#  'connective_tissue_disease',
#  'consolidation',
#  'coronary_aretry_calcium',
#  'coronary_artery]_[left_ascending_artery]_coronary_artery_dilatation',
#  'coronary_artery_calcification',
#  'coronary_artery_calcium',
#  'coronary_artery_dilatation',
#  'coronary_artery_disease',
#  'coronary_calcium',
#  'coronary_plaque',
#  'coronary_stenting',
#  'coronaryartery_calcium',
#  'cryoablation,[RUL]_consolidation',
#  'cryoablation_sites',
#  'cryoablation_tract_soft_tissue',
#  'cystic_fibrosis',
#  'degenerative_arthritis',
#  'delayed_myocardial_enhancement',
#  'descending_aorta_dilatation',
#  'descending_aorta_stent',
#  'descending_thoracic_aorta_aneurysmal_dilatation',
#  'descending_thoracic_aortic_aneurysm',
#  'diverticulum',
#  'drug_induced',
#  'drug_reaction',
#  'drug_related_change',
#  'empyema',
#  'endobronchial_nodule',
#  'endoleak',
#  'endovascular_repair',
#  'esophageal_dilatation',
#  'esophageal_perforation',
#  'esophageal_resection',
#  'ex_vacuo',
#  'excluded_false_lumen',
#  'exudate',
#  'fibrosis',
#  'fissural_nodularity',
#  'fissure]_m]_pulmonary_nodule',
#  'fissure]_m]_pulmonary_nodule',
#  'fissure]_pulmonary_nodule',
#  'fluid_collection',
#  'focal_fibrosis',
#  'follow_up',
#  'fracture',
#  'fungal_infection',
#  'gastric_wall_thickening',
#  'glass]_[solid]_pulmonary_nodule',
#  'glass]_centrilobular_pulmonary_nodules',
#  'glass]_pulmonary nodule',
#  'glass]_pulmonary_nodule',
#  'graft]_low_attenuated_lesion',
#  'granulomatous_inflammation',
#  'groud_glass_opacity',
#  'ground_glass_opacity',
#  'ground_glass_opcacity',
#  'hemangioma',
#  'hematogenous_malignancy',
#  'hematologic_malignanacy',
#  'hematologic_malignancy',
#  'hepatic_hydrothorax',
#  'hepatic_lesion',
#  'hepatic_metastasis',
#  'heterogeneous_bone_density',
#  'hiatal_hernia',
#  'hilar_invasion',
#  'honeycombing',
#  'humerus_fracture',
#  'hydropneumothorax',
#  'hypersensitivity_pneumonitis',
#  'hypertrophic_cardiomyopathy',
#  'hypodense_area',
#  'in_bud]_centrilobular_pulmonary_nodules',
#  'increasel]_[LLL]_[tree_in_bud]_pulmonary_centrilobular_nodules',
#  'indetermiante',
#  'indetermiate',
#  'indeterminate',
#  'indeterminate]_compression_fracture',
#  'indeterminate]_infection',
#  'infection',
#  'infection [risk]_malignancy',
#  'infection_sequela',
#  'infection_sequelae',
#  'infection_sequlae',
#  'inflammation',
#  'injury',
#  'interlobular_septal_thickening',
#  'intermedius]_[malignant]_airway_obstruction',
#  'intermedius]_bronchial_obstruction',
#  'interstitial_lung_disease',
#  'interstitial_lung_fibrosis',
#  'intracardiac_thrombus',
#  'intramural_hematoma',
#  'intrapulmonary_LN',
#  'intrathoracic_disease',
#  'intubation',
#  'irregular_nodular_opacity',
#  'kidney_lesion',
#  'linear_opacity',
#  'lingula]_scar',
#  'lingular]_[1.2cm]_[subpleural]_pulmonary_nodule',
#  'lingular]_[multiple]_[small]_pulmonary_nodule',
#  'lingular]_atelectasis',
#  'lingular]_treatment_related_change',
#  'lobectomy',
#  'local_recurrence',
#  'luminal_narrowing',
#  'lung_cancer',
#  'lung_fibrosis',
#  'lung_injury',
#  'lung_lesion',
#  'lung_metastasis',
#  'lung_nodule',
#  'lung_transplantation',
#  'lymphademopathy',
#  'lymphadenopathy',
#  'lymphangitic_carcinomatosis',
#  'lymphangitic_metastasis',
#  'lymphdenopathy',
#  'lymphocele',
#  'lymphoma',
#  'lymphoproliferative_disease',
#  'lympoma',
#  'lyphomatoid_granulomatosis',
#  'main]_coronary_mixed_plaque',
#  'malignancy',
#  'malignancy_burden',
#  'malignant_pleural_effusion',
#  'mammary]_LN',
#  'mammary]_m]_LN',
#  'mass',
#  'masslike_consolidation',
#  'mastitis',
#  'meastasis',
#  'mediastinal]_lymphdenopathy',
#  'mediastinal_lesion',
#  'mediastinal_mass',
#  'mesothelioma',
#  'metastasis',
#  'metastasis [unchanged]_[RML]_bronchial_obstruction',
#  'metastsis',
#  'metstasis',
#  'mid_descending_thoracic_aorta_contour_abnormality',
#  'miliary_pulmonary_nodules',
#  'mitral_annular_calcification',
#  'mosaic_attenuation',
#  'mucous_impaction',
#  'mucus_impaction',
#  'mucus_plugging',
#  'multifocal_infection',
#  'multifocal_pneumonia',
#  'multiple_myeloma',
#  'mycetoma',
#  'necrotizing_component',
#  'neoplasm',
#  'neural_foramen_involvement',
#  'nodular_consolidation',
#  'nodular_pleural_thickening',
#  'nodularity',
#  'nodules',
#  'nonspecific',
#  'normal_tracheal_caliber',
#  'obstructive_allograft_syndrome',
#  'obstructive_pulmonary_disease',
#  'occluded_coronary_graft',
#  'of_Fallot_repair]_postoperative_change',
#  'old_LV_apical_infarction',
#  'opacities',
#  'opacity',
#  'organizing_pneumonia',
#  'pancreas_lesion',
#  'paraesophageal_varix',
#  'patent_coronary_graft',
#  'patent_vascular_bypass',
#  'pathologic_fracture',
#  'penetrating_atherosclerotic_ulcer',
#  'penetrating_ulcer',
#  'perforation',
#  'peribronchial_opacity',
#  'peribronchovascular_pulmonary_nodules',
#  'pericardial_effusion',
#  'pericardial_nodularity',
#  'pericarditis',
#  'peritoneal_nodularity',
#  'pilmonary_edema',
#  'plaque',
#  'plerual_effusion',
#  'pleural effusion',
#  'pleural_carcinomatosis',
#  'pleural_effusion',
#  'pleural_enhancement',
#  'pleural_invasion',
#  'pleural_metastasis',
#  'pleural_nodular_thickening',
#  'pleural_nodularity',
#  'pleural_nodule',
#  'pleural_plaque',
#  'pleural_thickening',
#  'plueral_metastasis',
#  'pneumomediastinum',
#  'pneumonia',
#  'pneumothorax',
#  'polyspenia_syndrome',
#  'polysplenia_syndrome',
#  'porta_hepatis_lymphadeopathy',
#  'portal_hypertensive_change',
#  'post_procedural_scar',
#  'post_surgical_scar',
#  'post_transplant_lymphoproliferatice_disorder',
#  'posterior]_expiratory_tracheal_narrowoing',
#  'postoperative_change',
#  'postoperative_cjange',
#  'postprocedural_change',
#  'poststenotic_dilatation',
#  'primary_malignancy',
#  'prisk]_metastasis',
#  'pulmoanry_edema',
#  'pulmoanry_nodule',
#  'pulmonaey_embolism',
#  'pulmonary nodules',
#  'pulmonary_adenocarcinoma_spectrum_disease',
#  'pulmonary_adenocarcinoma_spectrum_lesion',
#  'pulmonary_arteriovenous_malformation',
#  'pulmonary_artery_dilatation',
#  'pulmonary_centrilobular_nodules',
#  'pulmonary_disease',
#  'pulmonary_ebolism',
#  'pulmonary_edema',
#  'pulmonary_embolism',
#  'pulmonary_emolism',
#  'pulmonary_emphysema',
#  'pulmonary_hamartoma',
#  'pulmonary_hemorrhage',
#  'pulmonary_hypertension',
#  'pulmonary_infarction',
#  'pulmonary_lesion',
#  'pulmonary_mass',
#  'pulmonary_metastasis',
#  'pulmonary_nodule',
#  'pulmonary_nodule. [decrease]_[RUL]_consolidation',
#  'pulmonary_nodules',
#  'pulmonary_opacity',
#  'pulmonary_sarcoidosis',
#  'pulmonary_tuberculosis',
#  'pulmonary_vein_stenosis',
#  'pulmonary_venooclusive_disease',
#  'pulmonary_venous_variation',
#  'pulmonry_artery_dilatation',
#  'punchanged]_thyroid_goiter',
#  'radiation_chage',
#  'radiation_change',
#  'radiation_fibrosis',
#  'radiation_pneumonitis',
#  'random_pulmonary_nodules',
#  'reactive',
#  'reactive [risk]_lymphoproliferative_disease',
#  'recess]_pulmonary_nodule',
#  'recurrence',
#  'recurrent_disease',
#  'recurrent_pnaumothorax_cause',
#  'recurrent_tumor',
#  'reexpansion_pulminary_edema',
#  'rejection',
#  'rejection_sequelae',
#  'related]_[right]_artrial_thrombosis',
#  'renal_cyst',
#  'renal_nodule',
#  'residual_tumor',
#  'respiratory_bronchiolitis',
#  'reticulation',
#  'rib_fracture',
#  'rib_metastasis',
#  'right_heart_strain',
#  'round_atelectasis',
#  'sarcoidosis',
#  'sarcoidosis_sequela',
#  'scar',
#  'sclerotic',
#  'sclerotic_bone_lesion',
#  'segment]_m]_pulmonary_nodule',
#  'segment]_m]_[ground_glass]_pulmonary_nodule',
#  'segment]_[ground_glass]_pulmonary_nodule',
#  'segment]_centrilobular_pulmonary_nodules',
#  'segment]_ground_glass_opacity',
#  'segment]_nodular_consolidation',
#  'septal_thickening',
#  'septic_emboli',
#  'significant_coronary_stenosis',
#  'small_airway_disease',
#  'small_airway_thickening',
#  'small_vessel_disease',
#  'soft_tissue_lesion',
#  'soft_tissue_lesions',
#  'solid]_pulmonary_nodule',
#  'solid]_pulmonary_nodulem [risk]_lung_cancer',
#  'solitary_fibrous_tumor',
#  'spine]_bone_metastasis',
#  'splenic_hypodensity',
#  'splenic_infarction',
#  'splenomegaly',
#  'sternal_defect',
#  'sternal_fracture',
#  'sternal_osteomyelitis',
#  'sternotomy_offset',
#  'straight_back_syndrome',
#  'subcutaneous_emphysema',
#  'subcutaneous_nodule',
#  'subpectoral_lymphadenopathy',
#  'superior_segment]_ground_glass_opacity',
#  'supleural_nodule',
#  'tension_hydrothorax',
#  'thoracic_abnormality',
#  'thoracic_abscess',
#  'thoracic_aorta_atherpsclerosis',
#  'thoracic_aorta_dilatation',
#  'thoracic_disease',
#  'thoracic_endograft',
#  'thrombosed_aortic_aneurysm',
#  'thrombus',
#  'thymic_cyst',
#  'thymic_neoplasm',
#  'thyroid_nodule',
#  'to_mid]_[thoracic_VB]_epidural_soft_tissue_lesion',
#  'total_atelectasis',
#  'total_calcium_score',
#  'traction_bronchiectasis',
#  'trapped_lung',
#  'treated_malignancy',
#  'treated_metastasis',
#  'treatment_related_change',
#  'tuberculosis',
#  'tuberculosis_infection',
#  'tuberculosis_sequelae',
#  'tumor',
#  'tumor_invasion',
#  'tumor_recurrence',
#  'type_B_aortic_dissection',
#  'type_ii_endoleak',
#  'vascular_abnormality',
#  'vasculitis',
#  'venolymphatic_obstruction',
#  'venoocclusive_disease',
#  'venous_compression',
#  'venous_dilatation',
#  'venous_narrowing',
#  'venous_thrombosis',
#  'venous_thrombus',
#  'ventricle]_cardiac_infarct',
#  'ventricular_aneurysm',
#  'ventricular_dilatation',
#  'ventricular_enlargement',
#  'ventricular_infection_sequelae',
#  'vertebra_plana',
#  'vertebral_body_sclerosis',
#  'viral_infection',
#  'viral_pneumonia',
#  'wall]_[2.9cm]_[2.7cm]_soft_tissue_lesion',
#  'wall]_air_collection',
#  'wall]_fluid_collection',
#  'wall]_soft_tissue_lesion',
#  'wedge_resection',
#  'wege_resection',
#  'window]_LN'}

# %%
# USE NAIVE SPELL CHECKER
spell = SpellChecker()

naive_checked_descriptors = set()

for w in cleaned_descriptors:
    corrected = spell.correction(w)
    print('original: {}, predicted: {}'.format(w, corrected))
    naive_checked_descriptors.add(corrected)


naive_checked_descriptors
# Out:
# original: , predicted: a
# original: segmental, predicted: segmental
# original: scleroci, predicted: sclerosis
# original: perigraft, predicted: perigraft
# original: teralogy, predicted: trilogy
# original: brachiocephalic, predicted: brachiocephalic
# original: common, predicted: common
# original: anterior, predicted: anterior
# original: multifocal, predicted: multifocal
# original: sternal, predicted: sternal
# original: unhanged, predicted: unchanged
# original: rib, predicted: rib
# original: fatty, predicted: fatty
# original: infeior, predicted: inferior
# original: two, predicted: two
# original: left, predicted: left
# original: bronchus, predicted: bronchus
# original: LLL, predicted: all
# original: subcarainal, predicted: subcarainal
# original: humerus, predicted: humerus
# original: uchanged, predicted: changed
# original: unchanged, predicted: unchanged
# original: patchy, predicted: patchy
# original: unchaged, predicted: unchanged
# original: atypical, predicted: atypical
# original: upper, predicted: upper
# original: subpectoral, predicted: subpectoral
# original: indrease, predicted: increase
# original: thoracic, predicted: thoracic
# original: sp, predicted: sp
# original: increase, predicted: increase
# original: indeterminate, predicted: indeterminate
# original: subclavian, predicted: subclavian
# original: decrease, predicted: decrease
# original: negx, predicted: nex
# original: unchanaged, predicted: unchanged
# original: cannular, predicted: cannula
# original: BUL, predicted: but
# original: cystic, predicted: cystic
# original: Gortex, predicted: cortex
# original: RML, predicted: ml
# original: trace, predicted: trace
# original: type, predicted: type
# original: necrptic, predicted: necrotic
# original: spleen, predicted: spleen
# original: partial, predicted: partial
# original: basilar, predicted: basil
# original: diffuse, predicted: diffuse
# original: old, predicted: old
# original: right, predicted: right
# original: new, predicted: new
# original: major, predicted: major
# original: subcarinal, predicted: subcarinal
# original: rd, predicted: rd
# original: diaphragm, predicted: diaphragm
# original: subsegmental, predicted: subsegmental
# original: fissure, predicted: fissure
# original: enhancing, predicted: enhancing
# original: BLL, predicted: all
# original: tree, predicted: tree
# original: mandible, predicted: mandible
# original: lobulated, predicted: populated
# original: inferior, predicted: inferior
# original: tiny, predicted: tiny
# original: thoraic, predicted: thoracic
# original: probable, predicted: probable
# original: focal, predicted: focal
# original: noncalcified, predicted: noncalcified
# original: severe, predicted: severe
# original: pathologic, predicted: pathology
# original: aortopulmonary, predicted: portopulmonary
# original: small, predicted: small
# original: medistinal, predicted: mediastinal
# original: solid, predicted: solid
# original: splenic, predicted: splenic
# original: scapular, predicted: scapula
# original: biltaeral, predicted: bilateral
# original: sternoclavicular, predicted: sternoclavicular
# original: large, predicted: large
# original: multile, predicted: multiple
# original: lingular, predicted: singular
# original: risk, predicted: risk
# original: descending, predicted: descending
# original: postoperative, predicted: postoperative
# original: cm, predicted: cm
# original: apex, predicted: apex
# original: rigk, predicted: risk
# original: mediastinal, predicted: mediastinal
# original: TT, predicted: TT
# original: infrahilar, predicted: infrahilar
# original: fissural, predicted: fissures
# original: mtultiple, predicted: multiple
# original: malignant, predicted: malignant
# original: variable, predicted: variable
# original: aggravated, predicted: aggravated
# original: acute, predicted: acute
# original: RISK, predicted: RISK
# original: appandage, predicted: appendage
# original: surrouding, predicted: surrounding
# original: improved, predicted: improved
# original: medium, predicted: medium
# original: cardiophrenic, predicted: cardiophrenic
# original: hyperenhancing, predicted: hyperenhancing
# original: pulmonary, predicted: pulmonary
# original: massive, predicted: massive
# original: distal, predicted: distal
# original: chest, predicted: chest
# original: confirmed, predicted: confirmed
# original: RUL, predicted: run
# original: RBLL, predicted: roll
# original: rigt, predicted: right
# original: chronic, predicted: chronic
# original: T, predicted: T
# original: main, predicted: main
# original: mm, predicted: mm
# original: reactive, predicted: reactive
# original: multiple, predicted: multiple
# original: cavitary, predicted: cavity
# original: azygoesophageal, predicted: azygoesophageal
# original: LUL, predicted: LUL
# original: category, predicted: category
# original: necrotic, predicted: necrotic
# original: uncahnged, predicted: unchanged
# original: borderline, predicted: borderline
# original: loculated, predicted: located
# original: extrapleural, predicted: extrapleural
# original: esophagus, predicted: esophagus
# original: RLL, predicted: RLL
# original: pleural, predicted: pleural
# original: lower, predicted: lower
# original: lung, predicted: lung
# original: treated, predicted: treated
# original: SVC, predicted: sic
# original: costophrenic, predicted: costophrenic
# original: recurrence, predicted: recurrence
# original: bilateral, predicted: bilateral
# original: groud, predicted: group
# original: nodular, predicted: nodular
# original: exudative, predicted: educative
# original: comminuted, predicted: committed
# original: glenoid, predicted: leonid
# original: internal, predicted: internal
# original: paratracheal, predicted: paratracheal
# original: part, predicted: part
# original: subpleural, predicted: subpleural
# original: negex, predicted: negev
# original: negnex, predicted: nene
# original: mid, predicted: mid
# original: catheter, predicted: catheter
# original: apical, predicted: apical
# original: BML, predicted: BML
# original: mo, predicted: mo
# original: lytic, predicted: lytic
# original: unchange, predicted: unchanged
# original: recurrent, predicted: recurrent
# original: cardiomegaly, predicted: cardiomegaly
# original: superior, predicted: superior
# original: reated, predicted: created
# original: sternum, predicted: sternum
# original: th, predicted: th
# original: arch, predicted: arch
# original: brachicephalic, predicted: brachicephalic
# original: necrotizing, predicted: necrotising
# original: clavicle, predicted: clavicle
# original: AP, predicted: AP
# original: intercostal, predicted: intercostal
# original: decreased, predicted: decreased
# original: LLLcm, predicted: lelc
# original: manubrium, predicted: manubrium
# original: L, predicted: L
# original: three, predicted: three
# original: remote, predicted: remote
# original: axillary, predicted: axillary
# original: perihilar, predicted: perihilar
# original: decrese, predicted: decrease
# original: breast, predicted: breast
# original: minor, predicted: minor
# original: serosanguineous, predicted: serosanguineous
# original: moderate, predicted: moderate
# original: sclerotic, predicted: sclerosis
# original: isthmus, predicted: isthmus
# original: rec, predicted: rec
# original: age, predicted: age
# original: periaortic, predicted: periaortic
# original: mild, predicted: mild
# original: GGN, predicted: gon
# original: calcified, predicted: calcified
# original: superimposed, predicted: superimposed
# original: ground, predicted: ground
# original: supraclavicular, predicted: supraclavicular
# original: hilar, predicted: hilary
# {'AP',
#  'BML',
#  'L',
#  'LUL',
#  'RISK',
#  'RLL',
#  'T',
#  'TT',
#  'a',
#  'acute',
#  'age',
#  'aggravated',
#  'all',
#  'anterior',
#  'apex',
#  'apical',
#  'appendage',
#  'arch',
#  'atypical',
#  'axillary',
#  'azygoesophageal',
#  'basil',
#  'bilateral',
#  'borderline',
#  'brachicephalic',
#  'brachiocephalic',
#  'breast',
#  'bronchus',
#  'but',
#  'calcified',
#  'cannula',
#  'cardiomegaly',
#  'cardiophrenic',
#  'category',
#  'catheter',
#  'cavity',
#  'changed',
#  'chest',
#  'chronic',
#  'clavicle',
#  'cm',
#  'committed',
#  'common',
#  'confirmed',
#  'cortex',
#  'costophrenic',
#  'created',
#  'cystic',
#  'decrease',
#  'decreased',
#  'descending',
#  'diaphragm',
#  'diffuse',
#  'distal',
#  'educative',
#  'enhancing',
#  'esophagus',
#  'extrapleural',
#  'fatty',
#  'fissure',
#  'fissures',
#  'focal',
#  'gon',
#  'ground',
#  'group',
#  'hilary',
#  'humerus',
#  'hyperenhancing',
#  'improved',
#  'increase',
#  'indeterminate',
#  'inferior',
#  'infrahilar',
#  'intercostal',
#  'internal',
#  'isthmus',
#  'large',
#  'left',
#  'lelc',
#  'leonid',
#  'located',
#  'lower',
#  'lung',
#  'lytic',
#  'main',
#  'major',
#  'malignant',
#  'mandible',
#  'manubrium',
#  'massive',
#  'mediastinal',
#  'medium',
#  'mid',
#  'mild',
#  'minor',
#  'ml',
#  'mm',
#  'mo',
#  'moderate',
#  'multifocal',
#  'multiple',
#  'necrotic',
#  'necrotising',
#  'negev',
#  'nene',
#  'new',
#  'nex',
#  'nodular',
#  'noncalcified',
#  'old',
#  'paratracheal',
#  'part',
#  'partial',
#  'patchy',
#  'pathology',
#  'periaortic',
#  'perigraft',
#  'perihilar',
#  'pleural',
#  'populated',
#  'portopulmonary',
#  'postoperative',
#  'probable',
#  'pulmonary',
#  'rd',
#  'reactive',
#  'rec',
#  'recurrence',
#  'recurrent',
#  'remote',
#  'rib',
#  'right',
#  'risk',
#  'roll',
#  'run',
#  'scapula',
#  'sclerosis',
#  'segmental',
#  'serosanguineous',
#  'severe',
#  'sic',
#  'singular',
#  'small',
#  'solid',
#  'sp',
#  'spleen',
#  'splenic',
#  'sternal',
#  'sternoclavicular',
#  'sternum',
#  'subcarainal',
#  'subcarinal',
#  'subclavian',
#  'subpectoral',
#  'subpleural',
#  'subsegmental',
#  'superimposed',
#  'superior',
#  'supraclavicular',
#  'surrounding',
#  'th',
#  'thoracic',
#  'three',
#  'tiny',
#  'trace',
#  'treated',
#  'tree',
#  'trilogy',
#  'two',
#  'type',
#  'unchanged',
#  'upper',
#  'variable'}

# %%
without_brackets_entities = set()
with_brackets_entities = set()

for entity in uncleaned_entities:
    if '[' in entity or ']' in entity:
        with_brackets_entities.add(entity)
    else:
        without_brackets_entities.add(entity)

# %%
without_brackets_entities
# Out:
# {'AAH',
#  'ADH',
#  'AIS',
#  'AML_related',
#  'CABG',
#  'Erdheim_Chester disease',
#  'IPF',
#  'LN',
#  'LN_metastasis',
#  'LV_enlargement',
#  'Langerhans_cell_histiocytosis',
#  'MAC',
#  'MIA',
#  'Morgagni_hernia',
#  'NISP',
#  'NSIP',
#  'NTM',
#  'NTM_infection',
#  'Port_A_Cath_clot',
#  'RB_ILD',
#  'SVC_narrowing',
#  'SVC_stent',
#  'SVC_thrombosis',
#  'UIP',
#  'abdominal_aorta_dilatation',
#  'abnormality',
#  'achalasia',
#  'acute_aortic_syndrome',
#  'acute_disease',
#  'acute_injury',
#  'acute_lung_injury',
#  'acute_rejection',
#  'adenmatous_hyperplasia',
#  'adrenal_gland_nodule',
#  'adrenal_nodule',
#  'aggravated_disease',
#  'aggravated_metastasis',
#  'air_trapping',
#  'airway_impaction',
#  'airway_infection',
#  'airway_lesion',
#  'airway_obstruction',
#  'airway_thickening',
#  'allergic_bronchopulmonary_aspergillosis',
#  'alveolar_hemorrhage',
#  'aorta_pseudoaneurysm',
#  'aortic_abnormality',
#  'aortic_arch_dilatation',
#  'aortic_dissection',
#  'aortic_stent',
#  'aortic_stent_graft',
#  'aortic_valve_calcification',
#  'aplastic_anemia',
#  'arterial_aneurysm',
#  'artery_aneurysm',
#  'arthritis',
#  'asceding_aorta_dilatation',
#  'ascending_aorta_dilatation',
#  'ascending_aorta_graft_repair',
#  'ascending_aorta_wall_thickening',
#  'ascending_arota_dilatation',
#  'ascites',
#  'ascneding_aorta_dilatation ',
#  'aspiration',
#  'aspiration_pneumonia',
#  'aspiration_sequela',
#  'atelectasis',
#  'atrial_enlargement',
#  'atrial_thrombus',
#  'atypical_infection',
#  'axillary_lymphdenopathy',
#  'bacterial_infection',
#  'bacterial_pneumonia',
#  'benign',
#  'blood_clot',
#  'bone_invasion',
#  'bone_involvement',
#  'bone_lesion',
#  'bone_lesions',
#  'bone_metastasis',
#  'breast_nodule',
#  'breast_prosthesis_calcification',
#  'breast_reconstruction',
#  'breat_mass',
#  'bronchial_obstruction',
#  'bronchial_wall_thickening',
#  'bronchiectasis',
#  'bronchiolitis_obliterans',
#  'bronchitis',
#  'broncholith',
#  'bronchopleural_fistula',
#  'bronchopneumonia',
#  'bronchus_invasion',
#  'bulla',
#  'burst_fracture',
#  'calcification',
#  'calcified_granuloma',
#  'calcified_plaque',
#  'calcium_score',
#  'capillary_hemangiomatosis',
#  'cardiomegaly',
#  'cardiophrenic_LN',
#  'cardiovascular_disease_evaluation',
#  'category_5',
#  'catheter_fragment',
#  'cavitary_nodule',
#  'central_venous_obstruction',
#  'centrilobular_groud_glass_opacity',
#  'centrilobular_ground_glass_opacity',
#  'centrilobular_nodules',
#  'centrilobular_pulmonary_nodules',
#  'centrilobular_pulmonary_opacities',
#  'chest_wall_defect',
#  'chest_wall_mass',
#  'chest_wall_nodule',
#  'chronic_NTM_infection',
#  'chronic_airway_disease',
#  'chronic_airway_infection',
#  'chronic_hypersensitivity_pneumonitis',
#  'chronic_infection',
#  'chronic_rejection',
#  'clavicular_fracture',
#  'coarctation_of_aorta',
#  'coccidioidomycosis',
#  'coccidiomycosis',
#  'collapse',
#  'colonic_pneumonatosis',
#  'complication',
#  'compression_deformity',
#  'compression_fracture',
#  'connective_tissue_disease',
#  'consolidation',
#  'coronary_aretry_calcium',
#  'coronary_artery_calcification',
#  'coronary_artery_calcium',
#  'coronary_artery_dilatation',
#  'coronary_artery_disease',
#  'coronary_calcium',
#  'coronary_plaque',
#  'coronary_stenting',
#  'coronaryartery_calcium',
#  'cryoablation_sites',
#  'cryoablation_tract_soft_tissue',
#  'cystic_fibrosis',
#  'degenerative_arthritis',
#  'delayed_myocardial_enhancement',
#  'descending_aorta_dilatation',
#  'descending_aorta_stent',
#  'descending_thoracic_aorta_aneurysmal_dilatation',
#  'descending_thoracic_aortic_aneurysm',
#  'diverticulum',
#  'drug_induced',
#  'drug_reaction',
#  'drug_related_change',
#  'empyema',
#  'endobronchial_nodule',
#  'endoleak',
#  'endovascular_repair',
#  'esophageal_dilatation',
#  'esophageal_perforation',
#  'esophageal_resection',
#  'ex_vacuo',
#  'excluded_false_lumen',
#  'exudate',
#  'fibrosis',
#  'fissural_nodularity',
#  'fluid_collection',
#  'focal_fibrosis',
#  'follow_up',
#  'fracture',
#  'fungal_infection',
#  'gastric_wall_thickening',
#  'granulomatous_inflammation',
#  'groud_glass_opacity',
#  'ground_glass_opacity',
#  'ground_glass_opcacity',
#  'hemangioma',
#  'hematogenous_malignancy',
#  'hematologic_malignanacy',
#  'hematologic_malignancy',
#  'hepatic_hydrothorax',
#  'hepatic_lesion',
#  'hepatic_metastasis',
#  'heterogeneous_bone_density',
#  'hiatal_hernia',
#  'hilar_invasion',
#  'honeycombing',
#  'humerus_fracture',
#  'hydropneumothorax',
#  'hypersensitivity_pneumonitis',
#  'hypertrophic_cardiomyopathy',
#  'hypodense_area',
#  'indetermiante',
#  'indetermiate',
#  'indeterminate',
#  'infection',
#  'infection_sequela',
#  'infection_sequelae',
#  'infection_sequlae',
#  'inflammation',
#  'injury',
#  'interlobular_septal_thickening',
#  'interstitial_lung_disease',
#  'interstitial_lung_fibrosis',
#  'intracardiac_thrombus',
#  'intramural_hematoma',
#  'intrapulmonary_LN',
#  'intrathoracic_disease',
#  'intubation',
#  'irregular_nodular_opacity',
#  'kidney_lesion',
#  'linear_opacity',
#  'lobectomy',
#  'local_recurrence',
#  'luminal_narrowing',
#  'lung_cancer',
#  'lung_fibrosis',
#  'lung_injury',
#  'lung_lesion',
#  'lung_metastasis',
#  'lung_nodule',
#  'lung_transplantation',
#  'lymphademopathy',
#  'lymphadenopathy',
#  'lymphangitic_carcinomatosis',
#  'lymphangitic_metastasis',
#  'lymphdenopathy',
#  'lymphocele',
#  'lymphoma',
#  'lymphoproliferative_disease',
#  'lympoma',
#  'lyphomatoid_granulomatosis',
#  'malignancy',
#  'malignancy_burden',
#  'malignant_pleural_effusion',
#  'mass',
#  'masslike_consolidation',
#  'mastitis',
#  'meastasis',
#  'mediastinal_lesion',
#  'mediastinal_mass',
#  'mesothelioma',
#  'metastasis',
#  'metastsis',
#  'metstasis',
#  'mid_descending_thoracic_aorta_contour_abnormality',
#  'miliary_pulmonary_nodules',
#  'mitral_annular_calcification',
#  'mosaic_attenuation',
#  'mucous_impaction',
#  'mucus_impaction',
#  'mucus_plugging',
#  'multifocal_infection',
#  'multifocal_pneumonia',
#  'multiple_myeloma',
#  'mycetoma',
#  'necrotizing_component',
#  'neoplasm',
#  'neural_foramen_involvement',
#  'nodular_consolidation',
#  'nodular_pleural_thickening',
#  'nodularity',
#  'nodules',
#  'nonspecific',
#  'normal_tracheal_caliber',
#  'obstructive_allograft_syndrome',
#  'obstructive_pulmonary_disease',
#  'occluded_coronary_graft',
#  'old_LV_apical_infarction',
#  'opacities',
#  'opacity',
#  'organizing_pneumonia',
#  'pancreas_lesion',
#  'paraesophageal_varix',
#  'patent_coronary_graft',
#  'patent_vascular_bypass',
#  'pathologic_fracture',
#  'penetrating_atherosclerotic_ulcer',
#  'penetrating_ulcer',
#  'perforation',
#  'peribronchial_opacity',
#  'peribronchovascular_pulmonary_nodules',
#  'pericardial_effusion',
#  'pericardial_nodularity',
#  'pericarditis',
#  'peritoneal_nodularity',
#  'pilmonary_edema',
#  'plaque',
#  'plerual_effusion',
#  'pleural effusion',
#  'pleural_carcinomatosis',
#  'pleural_effusion',
#  'pleural_enhancement',
#  'pleural_invasion',
#  'pleural_metastasis',
#  'pleural_nodular_thickening',
#  'pleural_nodularity',
#  'pleural_nodule',
#  'pleural_plaque',
#  'pleural_thickening',
#  'plueral_metastasis',
#  'pneumomediastinum',
#  'pneumonia',
#  'pneumothorax',
#  'polyspenia_syndrome',
#  'polysplenia_syndrome',
#  'porta_hepatis_lymphadeopathy',
#  'portal_hypertensive_change',
#  'post_procedural_scar',
#  'post_surgical_scar',
#  'post_transplant_lymphoproliferatice_disorder',
#  'postoperative_change',
#  'postoperative_cjange',
#  'postprocedural_change',
#  'poststenotic_dilatation',
#  'primary_malignancy',
#  'pulmoanry_edema',
#  'pulmoanry_nodule',
#  'pulmonaey_embolism',
#  'pulmonary nodules',
#  'pulmonary_adenocarcinoma_spectrum_disease',
#  'pulmonary_adenocarcinoma_spectrum_lesion',
#  'pulmonary_arteriovenous_malformation',
#  'pulmonary_artery_dilatation',
#  'pulmonary_centrilobular_nodules',
#  'pulmonary_disease',
#  'pulmonary_ebolism',
#  'pulmonary_edema',
#  'pulmonary_embolism',
#  'pulmonary_emolism',
#  'pulmonary_emphysema',
#  'pulmonary_hamartoma',
#  'pulmonary_hemorrhage',
#  'pulmonary_hypertension',
#  'pulmonary_infarction',
#  'pulmonary_lesion',
#  'pulmonary_mass',
#  'pulmonary_metastasis',
#  'pulmonary_nodule',
#  'pulmonary_nodules',
#  'pulmonary_opacity',
#  'pulmonary_sarcoidosis',
#  'pulmonary_tuberculosis',
#  'pulmonary_vein_stenosis',
#  'pulmonary_venooclusive_disease',
#  'pulmonary_venous_variation',
#  'pulmonry_artery_dilatation',
#  'radiation_chage',
#  'radiation_change',
#  'radiation_fibrosis',
#  'radiation_pneumonitis',
#  'random_pulmonary_nodules',
#  'reactive',
#  'recurrence',
#  'recurrent_disease',
#  'recurrent_pnaumothorax_cause',
#  'recurrent_tumor',
#  'reexpansion_pulminary_edema',
#  'rejection',
#  'rejection_sequelae',
#  'renal_cyst',
#  'renal_nodule',
#  'residual_tumor',
#  'respiratory_bronchiolitis',
#  'reticulation',
#  'rib_fracture',
#  'rib_metastasis',
#  'right_heart_strain',
#  'round_atelectasis',
#  'sarcoidosis',
#  'sarcoidosis_sequela',
#  'scar',
#  'sclerotic',
#  'sclerotic_bone_lesion',
#  'septal_thickening',
#  'septic_emboli',
#  'significant_coronary_stenosis',
#  'small_airway_disease',
#  'small_airway_thickening',
#  'small_vessel_disease',
#  'soft_tissue_lesion',
#  'soft_tissue_lesions',
#  'solitary_fibrous_tumor',
#  'splenic_hypodensity',
#  'splenic_infarction',
#  'splenomegaly',
#  'sternal_defect',
#  'sternal_fracture',
#  'sternal_osteomyelitis',
#  'sternotomy_offset',
#  'straight_back_syndrome',
#  'subcutaneous_emphysema',
#  'subcutaneous_nodule',
#  'subpectoral_lymphadenopathy',
#  'supleural_nodule',
#  'tension_hydrothorax',
#  'thoracic_abnormality',
#  'thoracic_abscess',
#  'thoracic_aorta_atherpsclerosis',
#  'thoracic_aorta_dilatation',
#  'thoracic_disease',
#  'thoracic_endograft',
#  'thrombosed_aortic_aneurysm',
#  'thrombus',
#  'thymic_cyst',
#  'thymic_neoplasm',
#  'thyroid_nodule',
#  'total_atelectasis',
#  'total_calcium_score',
#  'traction_bronchiectasis',
#  'trapped_lung',
#  'treated_malignancy',
#  'treated_metastasis',
#  'treatment_related_change',
#  'tuberculosis',
#  'tuberculosis_infection',
#  'tuberculosis_sequelae',
#  'tumor',
#  'tumor_invasion',
#  'tumor_recurrence',
#  'type_B_aortic_dissection',
#  'type_ii_endoleak',
#  'vascular_abnormality',
#  'vasculitis',
#  'venolymphatic_obstruction',
#  'venoocclusive_disease',
#  'venous_compression',
#  'venous_dilatation',
#  'venous_narrowing',
#  'venous_thrombosis',
#  'venous_thrombus',
#  'ventricular_aneurysm',
#  'ventricular_dilatation',
#  'ventricular_enlargement',
#  'ventricular_infection_sequelae',
#  'vertebra_plana',
#  'vertebral_body_sclerosis',
#  'viral_infection',
#  'viral_pneumonia',
#  'wedge_resection',
#  'wege_resection'}

# %%
# WE NEED TO MANUALLY ADD THE DESCRIPTORS
cleaned_with_brackets_entities = set()

for e in with_brackets_entities:
    cleaned_with_brackets_entities.add(e.split(']_')[-1])

# %%
cleaned_with_brackets_entities
# Out:
# {'CPAM',
#  'LN',
#  'Lung_RADs',
#  'air_collection',
#  'airway_obstruction',
#  'aortic_dissection',
#  'artrial_thrombosis',
#  'atelectasis',
#  'bone_metastasis',
#  'bronchial_narrowing',
#  'bronchial_obstruction',
#  'cardiac_infarct',
#  'centrilobular_pulmonary_nodules',
#  'compression_fracture',
#  'consolidation',
#  'coronary_artery_dilatation',
#  'coronary_disease',
#  'coronary_mixed_plaque',
#  'coronary_stenosis',
#  'endoleak',
#  'epidural_soft_tissue_lesion',
#  'expiratory_tracheal_narrowoing',
#  'fluid_collection',
#  'ground_glass_opacity',
#  'hyperdense_lesion',
#  'infection',
#  'intramural_hematoma',
#  'low_attenuated_lesion',
#  'lung_cancer',
#  'lymphdenopathy',
#  'lymphoproliferative_disease',
#  'malignancy',
#  'metastasis',
#  'myocardiac_infarction_sequalae',
#  'myocardial_bridging',
#  'nodular_consolidation',
#  'postoperative_change',
#  'pulmonary nodule',
#  'pulmonary_centrilobular_nodules',
#  'pulmonary_nodule',
#  'scar',
#  'soft_tissue_lesion',
#  'stump_thrombosis',
#  'thrombus',
#  'thyroid_goiter',
#  'treatment_related_change',
#  'ulcerative_plaque',
#  'vascular_obstruction'}

# %%
all_entities = without_brackets_entities.union(cleaned_with_brackets_entities)
print(all_entities)
# Out:
# {'postoperative_change', 'bronchitis', 'viral_pneumonia', 'pleural_nodular_thickening', 'hydropneumothorax', 'empyema', 'myocardial_bridging', 'pleural_nodule', 'hematologic_malignancy', 'hyperdense_lesion', 'ascites', 'supleural_nodule', 'coronary_calcium', 'wedge_resection', 'delayed_myocardial_enhancement', 'septal_thickening', 'rejection', 'intubation', 'malignant_pleural_effusion', 'ascending_aorta_graft_repair', 'fibrosis', 'pulmonary_venooclusive_disease', 'degenerative_arthritis', 'cardiovascular_disease_evaluation', 'masslike_consolidation', 'irregular_nodular_opacity', 'breast_prosthesis_calcification', 'mucous_impaction', 'humerus_fracture', 'aggravated_disease', 'coronary_stenosis', 'polyspenia_syndrome', 'CABG', 'fluid_collection', 'MAC', 'ventricular_infection_sequelae', 'neoplasm', 'primary_malignancy', 'epidural_soft_tissue_lesion', 'pneumomediastinum', 'breat_mass', 'lymphocele', 'aortic_arch_dilatation', 'vascular_abnormality', 'Erdheim_Chester disease', 'venous_narrowing', 'penetrating_ulcer', 'viral_infection', 'infection_sequlae', 'traction_bronchiectasis', 'adrenal_gland_nodule', 'pulmonaey_embolism', 'pulmonary_nodules', 'lymphdenopathy', 'bronchiolitis_obliterans', 'reticulation', 'vertebra_plana', 'reexpansion_pulminary_edema', 'nodular_pleural_thickening', 'thoracic_abnormality', 'category_5', 'fracture', 'portal_hypertensive_change', 'lobectomy', 'bone_invasion', 'pulmonary_adenocarcinoma_spectrum_disease', 'acute_disease', 'AIS', 'patent_coronary_graft', 'pulmonary nodules', 'mucus_plugging', 'mediastinal_mass', 'scar', 'follow_up', 'small_vessel_disease', 'ground_glass_opacity', 'small_airway_thickening', 'bulla', 'NTM_infection', 'infection_sequela', 'aspiration', 'necrotizing_component', 'bone_lesion', 'tuberculosis_sequelae', 'asceding_aorta_dilatation', 'small_airway_disease', 'pulmonary_infarction', 'local_recurrence', 'lymphadenopathy', 'coccidioidomycosis', 'alveolar_hemorrhage', 'esophageal_dilatation', 'hypertrophic_cardiomyopathy', 'calcification', 'fissural_nodularity', 'SVC_thrombosis', 'wege_resection', 'aspiration_pneumonia', 'colonic_pneumonatosis', 'cavitary_nodule', 'pleural_thickening', 'MIA', 'drug_induced', 'sternal_fracture', 'neural_foramen_involvement', 'hemangioma', 'capillary_hemangiomatosis', 'thyroid_nodule', 'IPF', 'bronchial_wall_thickening', 'pulmonary_hemorrhage', 'expiratory_tracheal_narrowoing', 'nonspecific', 'metastsis', 'round_atelectasis', 'infection', 'pericardial_nodularity', 'artrial_thrombosis', 'breast_nodule', 'lymphangitic_metastasis', 'descending_aorta_dilatation', 'calcified_granuloma', 'tumor', 'total_atelectasis', 'thoracic_abscess', 'chronic_rejection', 'thrombus', 'intracardiac_thrombus', 'consolidation', 'bacterial_infection', 'peribronchial_opacity', 'coronary_artery_calcium', 'Port_A_Cath_clot', 'calcified_plaque', 'mid_descending_thoracic_aorta_contour_abnormality', 'focal_fibrosis', 'gastric_wall_thickening', 'chronic_airway_infection', 'reactive', 'bone_lesions', 'coronary_aretry_calcium', 'pulmonary_metastasis', 'hepatic_metastasis', 'penetrating_atherosclerotic_ulcer', 'malignancy', 'SVC_narrowing', 'mucus_impaction', 'endovascular_repair', 'patent_vascular_bypass', 'burst_fracture', 'splenic_infarction', 'post_transplant_lymphoproliferatice_disorder', 'Lung_RADs', 'cardiac_infarct', 'pulmonary_centrilobular_nodules', 'ascneding_aorta_dilatation ', 'cardiophrenic_LN', 'NSIP', 'pleural_effusion', 'lymphoproliferative_disease', 'mycetoma', 'bronchial_obstruction', 'pleural effusion', 'pneumothorax', 'venous_thrombus', 'catheter_fragment', 'pneumonia', 'chronic_NTM_infection', 'LN_metastasis', 'centrilobular_groud_glass_opacity', 'honeycombing', 'aggravated_metastasis', 'lymphademopathy', 'adenmatous_hyperplasia', 'myocardiac_infarction_sequalae', 'infection_sequelae', 'airway_lesion', 'SVC_stent', 'meastasis', 'drug_related_change', 'venous_compression', 'opacities', 'right_heart_strain', 'cryoablation_sites', 'sarcoidosis', 'airway_thickening ...

# %%
all_descriptors = cleaned_descriptors #.union( set manual extraction of descriptors from with_brackets_entities )
print(all_descriptors)
# Out:
# {'', 'segmental', 'scleroci', 'perigraft', 'teralogy', 'brachiocephalic', 'common', 'anterior', 'multifocal', 'sternal', 'unhanged', 'rib', 'fatty', 'infeior', 'two', 'left', 'bronchus', 'LLL', 'subcarainal', 'humerus', 'uchanged', 'unchanged', 'patchy', 'unchaged', 'atypical', 'upper', 'subpectoral', 'indrease', 'thoracic', 'sp', 'increase', 'indeterminate', 'subclavian', 'decrease', 'negx', 'unchanaged', 'cannular', 'BUL', 'cystic', 'Gortex', 'RML', 'trace', 'type', 'necrptic', 'spleen', 'partial', 'basilar', 'diffuse', 'old', 'right', 'new', 'major', 'subcarinal', 'rd', 'diaphragm', 'subsegmental', 'fissure', 'enhancing', 'BLL', 'tree', 'mandible', 'lobulated', 'inferior', 'tiny', 'thoraic', 'probable', 'focal', 'noncalcified', 'severe', 'pathologic', 'aortopulmonary', 'small', 'medistinal', 'solid', 'splenic', 'scapular', 'biltaeral', 'sternoclavicular', 'large', 'multile', 'lingular', 'risk', 'descending', 'postoperative', 'cm', 'apex', 'rigk', 'mediastinal', 'TT', 'infrahilar', 'fissural', 'mtultiple', 'malignant', 'variable', 'aggravated', 'acute', 'RISK', 'appandage', 'surrouding', 'improved', 'medium', 'cardiophrenic', 'hyperenhancing', 'pulmonary', 'massive', 'distal', 'chest', 'confirmed', 'RUL', 'RBLL', 'rigt', 'chronic', 'T', 'main', 'mm', 'reactive', 'multiple', 'cavitary', 'azygoesophageal', 'LUL', 'category', 'necrotic', 'uncahnged', 'borderline', 'loculated', 'extrapleural', 'esophagus', 'RLL', 'pleural', 'lower', 'lung', 'treated', 'SVC', 'costophrenic', 'recurrence', 'bilateral', 'groud', 'nodular', 'exudative', 'comminuted', 'glenoid', 'internal', 'paratracheal', 'part', 'subpleural', 'negex', 'negnex', 'mid', 'catheter', 'apical', 'BML', 'mo', 'lytic', 'unchange', 'recurrent', 'cardiomegaly', 'superior', 'reated', 'sternum', 'th', 'arch', 'brachicephalic', 'necrotizing', 'clavicle', 'AP', 'intercostal', 'decreased', 'LLLcm', 'manubrium', 'L', 'three', 'remote', 'axillary', 'perihilar', 'decrese', 'breast', 'minor', 'serosanguineous', 'moderate', 'sclerotic', 'isthmus', 'rec', 'age', 'periaortic', 'mild', 'GGN', 'calcified', 'superimposed', 'ground', 'supraclavicular', 'hilar'}
